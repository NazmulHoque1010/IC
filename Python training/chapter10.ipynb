# %%
from pathlib import Path
Path('spam','bacon','eggs')
str(Path('spam', 'bacon', 'eggs'))
# Out:
# 'spam\\bacon\\eggs'

# %%
my_files=['embrylogy.pdf','Untitled.png']
for i in my_files:
    print(Path(r'C:\Users\Lenovo\Desktop',i))
# Out:
# C:\Users\Lenovo\Desktop\embrylogy.pdf
# C:\Users\Lenovo\Desktop\Untitled.png

# %%
print(Path('spam')/'bacon'/'eggs')
print(Path('spam')/Path('bacon/eggs'))
print(Path('spam')/Path('bacon','eggs'))
# Out:
# spam\bacon\eggs
# spam\bacon\eggs
# spam\bacon\eggs

# %%
Path.cwd() # currnet working directory
# Out:
# WindowsPath('c:/Users/Lenovo/Desktop/IC/Python training')

# %%
Path.home() # home directory of the pc
# Out:
# WindowsPath('C:/Users/Lenovo')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
os.makedirs('C:\\delicious\\walnut\\waffles') # making new folders and directories using os.makedirs()

# %%
Path(r'C:\\delicious\\spam').mkdir() # another way to make a folder not using os

# %%
Path.cwd().is_absolute()
# Out:
# True

# %%
# anchors
p=Path('C:/delicious/waffles')
p.anchor
# Out:
# 'C:\\'

# %%
p.parent
# Out:
# WindowsPath('C:/delicious')

# %%
p.name
# Out:
# 'waffles'

# %%
p.stem
# Out:
# 'waffles'

# %%
p.suffix
# Out:
# ''

# %%
p.drive
# Out:
# 'C:'

# %%
# parts
print(p.parts)
print(p.parts[2])
print(p.parts[0:2])
# Out:
# ('C:\\', 'delicious', 'waffles')
# waffles
# ('C:\\', 'delicious')

# %%
print(Path.cwd())
print(Path.cwd().parents[0])
print(Path.cwd().parents[1])
print(Path.cwd().parents[2])
print(Path.cwd().parents[3])
print(Path.cwd().parents[4])
# Out:
# c:\Users\Lenovo\Desktop\IC\Python training
# c:\Users\Lenovo\Desktop\IC
# c:\Users\Lenovo\Desktop
# c:\Users\Lenovo
# c:\Users
# c:\

# %%
calc_file = Path('C:/Windows/System32/calc.exe')
calc_file.stat()
# Out:
# os.stat_result(st_mode=33279, st_ino=2533274790973611, st_dev=1147694547, st_nlink=2, st_uid=0, st_gid=0, st_size=49152, st_atime=1789542069, st_mtime=1779911723, st_ctime=1779911723)

# %%
calc_file.stat().st_size
# Out:
# 49152

# %%
for name in Path('C:/Users/Lenovo/Desktop').glob('*'):
    print(name)
# Out:
# C:\Users\Lenovo\Desktop\30eff126-8330-4926-bbc6-d1d6e8c7f67e.jpg
# C:\Users\Lenovo\Desktop\471
# C:\Users\Lenovo\Desktop\desktop.ini
# C:\Users\Lenovo\Desktop\embrylogy.pdf
# C:\Users\Lenovo\Desktop\IC
# C:\Users\Lenovo\Desktop\Internet Download Manager.lnk
# C:\Users\Lenovo\Desktop\Land of 2 Rivers.pdf
# C:\Users\Lenovo\Desktop\Meeting
# C:\Users\Lenovo\Desktop\P3 workbook.pdf
# C:\Users\Lenovo\Desktop\P4 workbook.pdf
# C:\Users\Lenovo\Desktop\Person 1 - Chrome.lnk
# C:\Users\Lenovo\Desktop\PHALS Log_WH_Asset
# C:\Users\Lenovo\Desktop\PHALS Procurement
# C:\Users\Lenovo\Desktop\Roblox Player.lnk
# C:\Users\Lenovo\Desktop\Roblox Studio.lnk
# C:\Users\Lenovo\Desktop\RS-63
# C:\Users\Lenovo\Desktop\Untitled.png
# C:\Users\Lenovo\Desktop\Visual Studio Code.lnk
# C:\Users\Lenovo\Desktop\Word.lnk
# C:\Users\Lenovo\Desktop\Zoom Workplace.lnk
# C:\Users\Lenovo\Desktop\~$ok Review 2nd Half.docx

# %%
p=Path('spam.txt') # making a new text file
p.write_text('Hello World')  # writing something on to a text file
p.read_text()  # reading from a text file
# Out:
# 'Hello World'

# %%
p=Path('hello.txt')
p.write_text('Hello, world!')
# Out:
# 13

# %%
# opening a file
hello_file = open(r'C:\Users\Lenovo\Desktop\IC\Python training\hello.txt', 'r')

# %%
text=hello_file.read()
print(text)
# Out:
# Hello, world!

# %%
sonnet_file=open(r'C:\Users\Lenovo\Desktop\IC\Python training\sonnet29.txt','r')
n=sonnet_file.readlines()
print(n)
sonnet_file.close()
# Out:
# ["When, in disgrace with fortune and men's eyes,\n", 'I all alone beweep my outcast state,\n', 'And trouble deaf heaven with my bootless cries,\n', 'And look upon myself and curse my fate,']

# %%
# Writing
sfile=open(r'C:\Users\Lenovo\Desktop\IC\Python training\sonnet29.txt','a')
sfile.write("Hello there\n")
sfile.close()
sfile=open(r'C:\Users\Lenovo\Desktop\IC\Python training\sonnet29.txt','r')
sfile.readlines()
# Out:
# ["When, in disgrace with fortune and men's eyes,\n",
#  'I all alone beweep my outcast state,\n',
#  'And trouble deaf heaven with my bootless cries,\n',
#  'And look upon myself and curse my fate,Hello there\n',
#  'Hello there\n',
#  'Hello there\n',
#  'Hello there\n']
