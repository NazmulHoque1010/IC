# %%
import webbrowser
webbrowser.open('https://inventwithpython.com/')
# Out:
# True

# %%
'''webbrowser (built-in) — opens a URL in a browser tab.
requests — downloads web pages/files over HTTP(S).
bs4 (Beautiful Soup) — parses downloaded HTML to extract specific elements.
Selenium — directly controls a real browser (clicks, typing, scrolling) — needed for JS-heavy or login-gated sites.
Playwright — newer alternative to Selenium; supports headless mode (no visible browser window) and is generally more reliable about waiting for pages to load.'''

# %% [markdown]
# ![image.png](attachment:image.png)
