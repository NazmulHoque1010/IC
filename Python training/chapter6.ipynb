# %%
spam = ['cat', 'bat', 'rat', 'elephant']
print(spam[0])
print(spam[1:3])
print(spam[0:-1])
print(spam[1:])
print(spam[:2])
# Out:
# cat
# ['bat', 'rat']
# ['cat', 'bat', 'rat']
# ['bat', 'rat', 'elephant']
# ['cat', 'bat']

# %% [markdown]
# Leaving out the first index is the same as using 0, or the beginning of the list. Leaving out the second index is the same as using the length of the list, which will slice to the end of the list

# %%
# Value updating
spam[1] = 'aardvark'
spam
# Out:
# ['cat', 'aardvark', 'rat', 'elephant']

# %%
# List concatenation
print(spam+[1,2,3,4])
# Out:
# ['cat', 'aardvark', 'rat', 'elephant', 1, 2, 3, 4]

# %%
# List replication
print(spam*3)
# Out:
# ['cat', 'aardvark', 'rat', 'elephant', 'cat', 'aardvark', 'rat', 'elephant', 'cat', 'aardvark', 'rat', 'elephant']

# %%
# del 
del spam[2]
spam
# Out:
# ['cat', 'aardvark', 'elephant']

# %%
cats=[]
while True:
    new=input("Enter name of new cat: ")
    if new:
        cats.append(new)
    else:
        break
print(cats)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# in/not in operators
print("a" in cats)
print("b" not in cats)
print("z" not in cats)
# Out:
# True
# False
# True

# %%
# Unpacking
cat1,cat2,cat3,cat4=cats
print(cat2)
# Out:
# b

# %%
# enumerate
supplies = ['pens', 'staplers', 'flamethrowers', 'binders']
for index, item in enumerate(supplies):
    print('Index ' + str(index) + ' in supplies is: ' + item)
# Out:
# Index 0 in supplies is: pens
# Index 1 in supplies is: staplers
# Index 2 in supplies is: flamethrowers
# Index 3 in supplies is: binders

# %%
# random
import random
pets = ['Dog', 'Cat', 'Moose']
random.choice(pets)
# Out:
# 'Dog'

# %%
# shuffling
people = ['Alice', 'Bob', 'Carol', 'David']
random.shuffle(people)
people
# Out:
# ['Bob', 'David', 'Carol', 'Alice']

# %%
# index(), returns index of first appearance of the item
spam = ['hello', 'hi', 'howdy', 'heyas']
print(spam.index("hi"))
# Out:
# 1

# %%
# append()
spam = ['hello', 'hi', 'howdy', 'heyas']
spam.append("new")
print(spam)
# Out:
# ['hello', 'hi', 'howdy', 'heyas', 'new']

# %%
spam=["cat","dog","bat"]
spam.insert(2,"cow")
spam
# Out:
# ['cat', 'dog', 'cow', 'bat']

# %%
# remove, removes the first instace of the value given
spam.remove("cow")
spam
# Out:
# ['cat', 'dog', 'bat']

# %%
# sort() returns a list in ascending order when numbers and alphabetical order when in strings
spam.sort()
print(spam)
new=[2,5,8,3,1]
new.sort()
print(new)
new.sort(reverse=True)  # sort in descending order
print(new)
# Out:
# ['bat', 'cat', 'dog']
# [1, 2, 3, 5, 8]
# [8, 5, 3, 2, 1]

# %%
spam = ['Alice', 'ants', 'Bob', 'badgers', 'Carol', 'cats']
spam.sort()  # Capital letters appear first
print(spam)
# Out:
# ['Alice', 'Bob', 'Carol', 'ants', 'badgers', 'cats']

# %%
# reverse()
spam.reverse()
print(spam)
# Out:
# ['cats', 'badgers', 'ants', 'Carol', 'Bob', 'Alice']

# %%
# references
spam=[1,2,3,4,5]
eggs=spam
eggs[0]=100
print(spam)
print(eggs)
# Out:
# [100, 2, 3, 4, 5]
# [100, 2, 3, 4, 5]

# %%
# copy list
import copy
spam=[1,2,3,4,5]
new=copy.copy(spam)
new[2]=100
print(spam)
print(new)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 100, 4, 5]

# %% [markdown]
# Write a function that takes a list value as an argument and returns a string with all the items separated by a comma and a space, with and inserted before the last item. For example, passing the previous spam list to the function would return 'apples, bananas, tofu, and cats'. But your function should be able to work with any list value passed to it. Be sure to test the case where an empty list [] is passed to your function.

# %%
def joiner(arr):
    res=""
    for i,j in enumerate(arr):
        if i==len(arr)-2:
            res+=j+" "
        elif i!=len(arr)-1:
            res+=j+", "
        else:
            res+="and "+j
    return res
spam = ['apples', 'bananas', 'tofu', 'cats',"dogs"]
print(joiner(spam))
# Out:
# apples, bananas, tofu, cats and dogs
