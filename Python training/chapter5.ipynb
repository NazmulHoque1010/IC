# %%
# Raise
raise Exception("This is the error message")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Raise
# ----> 2 raise Exception("This is the error message")
#
# Exception: This is the error message

# %%
ages= [2,5,4,9,7,1]
ages.sort()
assert ages[0]<=ages[-1]

# %%
ages= [2,5,4,9,7,1]
ages.sort()
ages.reverse()
assert ages[0]<=ages[-1]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 ages.sort()
#       3 ages.reverse()
# ----> 4 assert ages[0]<=ages[-1]
#
# AssertionError:

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s -  %(levelname)s -  %(message)s')
logging.debug('Start of program')

def factorial(n):
    logging.debug('Start of factorial(' + str(n) + ')')
    if n==0 or n==1:
        return 1
    res=1
    for i in range(1,n+1):
        res*=i
    logging.debug('End of factorial(' + str(n) + ')')
    return res
print(factorial(5))
logging.debug('End of program')
# Out:
#  2026-09-15 14:18:26,759 -  DEBUG -  Start of program
#  2026-09-15 14:18:26,767 -  DEBUG -  Start of factorial(5)
#  2026-09-15 14:18:26,770 -  DEBUG -  End of factorial(5)
#  2026-09-15 14:18:26,772 -  DEBUG -  End of program
# 120

# %%
logging.basicConfig(filename='myProgramLog.txt', level=logging.DEBUG,
format=' %(asctime)s -  %(levelname)s -  %(message)s')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different. (That is, 'hello' and 'hello' are considered the same, as are 'goodbye' and 'GOODbye'.)

# %%
eggs="Hello"
bacon="heLLo"
eggs=eggs.lower()
bacon=bacon.lower()
assert eggs!=bacon
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 5
#       3 eggs=eggs.lower()
#       4 bacon=bacon.lower()
# ----> 5 assert eggs!=bacon
#
# AssertionError:

# %%
# Write an assert statement that always triggers an AssertionError
assert 1<1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Write an assert statement that always triggers an AssertionError
# ----> 2 assert 1<1
#
# AssertionError:
