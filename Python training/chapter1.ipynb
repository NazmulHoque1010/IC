# %%
#Exponential operator
print(2**4)
# Out:
# 16

# %%
# Modulus/Remainder
print(22%8)
# Out:
# 6

# %%
# Integer/Floor division
print(22//8)
# Out:
# 2

# %%
# Division
print(23/7)
# Out:
# 3.2857142857142856

# %%
# Precedence
print((5 - 1) * ((7 + 1) / (3 - 1)))
# Out:
# 16.0

# %%
# String concatenation
print("Alice"+"Bob")
print("Alice" * 5)
# Out:
# AliceBob
# AliceAliceAliceAliceAlice

# %% [markdown]
# ### Variables

# %%
a= "Hello"
print(a)
a="bye"
print(a)
# Out:
# Hello
# bye

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Input testing
print('Hello, world!')
print('What is your name?')  # Ask for their name.
my_name = input()
print('It is good to meet you, ' + my_name)
print('The length of your name is:')
print(len(my_name))
print('What is your age?')  # Ask for their age.
my_age = input()
print('You will be ' + str(int(my_age) + 1) + ' in a year.')
# Out:
# Hello, world!
# What is your name?
# It is good to meet you, as
# The length of your name is:
# 2
# What is your age?
# You will be 3 in a year.

# %%
# str() converts to string
print('I am ' + str(29) + ' years old.')
# Out:
# I am 29 years old.

# %%
# int() converts to int
print(int("52"))
print(int(3.14))
# Out:
# 52
# 3

# %%
# float() converts to float
print(float(3))
print(float("24"))
# Out:
# 3.0
# 24.0

# %%
age = input("What is your age: ")
print(f"You will be {int(age)+1} years old next year")
# Out:
# You will be 25 years old next year

# %%
# Text and number equivalence
print(42=="42")
print(42==42.0)
# Out:
# False
# True

# %%
# Round function
print(round(3.14))
print(round(7.7))
print(round(3.14,1))
print(round(7.7777,3))
print(round(2.5)) # rounds to nearest even
print(round(3.5)) # rounds to nearest even
# Out:
# 3
# 8
# 3.1
# 7.778
# 2
# 4

# %%
# abs() function
print(abs(25))
print(abs(-25))
print(abs(-3.14))
print(abs(0))
# Out:
# 25
# 25
# 3.14
# 0

# %% [markdown]
# decimal to binary representations

# %% [markdown]
# ![image.png](attachment:image.png)
