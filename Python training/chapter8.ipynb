# %%
spam="This is Alice's cat"
print(spam)
# Out:
# This is Alice's cat

# %%
# Excape sequences
spam='Say hi to Bob\'s mother.'
spam2= "You can go there but \n make sure to come back in time."
print(spam,spam2)

print("Hello there!\nHow are you?\nI\'m doing fine.")
# Out:
# Say hi to Bob's mother. You can go there but
#  make sure to come back in time.
# Hello there!
# How are you?
# I'm doing fine.

# %%
# raw string, treats backslash as part of the string
print(r'The file is in C:\Users\Alice\Desktop')
# Out:
# The file is in C:\Users\Alice\Desktop

# %%
# Multi-line strings
print('''Dear Alice,

Can you feed Eve's cat this weekend?

Sincerely,
Bob''')
# Out:
# Dear Alice,
#
# Can you feed Eve's cat this weekend?
#
# Sincerely,
# Bob

# %%
# in/not in keywords
print("hello" in "hello world")
# Out:
# True

# %%
# f strings
name = 'Al'
age = 4000
print(f'My name is {name}. I am {age} years old.')
# Out:
# My name is Al. I am 4000 years old.

# %%
name = 'Al'
age = 4000
print('My name is %s. I am %s years old.' % (name, age))
print('My name is {}. I am {} years old.'.format(name, age))
# Out:
# My name is Al. I am 4000 years old.
# My name is Al. I am 4000 years old.

# %%
# upper() and lower() methods
s="HeLLo wOrLD"
print(s.lower(), s.upper())
# Out:
# hello world HELLO WORLD

# %%
# isupper() and islower()
print("hello".islower())
print("GREAT".isupper())
# Out:
# True
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# startswith() and endswith() methods
print("HelloWorld".startswith("Hello"))
print("HelloWorld".endswith("ld"))
# Out:
# True
# True

# %%
# join() and split()
s=', '.join(['cats', 'rats', 'bats'])
print(s)

s="cats, rats, bats"
s=s.split(", ")
print(s)
# Out:
# cats, rats, bats
# ['cats', 'rats', 'bats']

# %%
# strip(), lstrip(), rstrip()
spam = '    Hello, World    '
print(spam.strip())
print(spam.lstrip())
print(spam.rstrip())
# Out:
# Hello, World
# Hello, World
#     Hello, World

# %%
spam = 'SpamSpamBaconSpamEggsSpamSpam'
spam=spam.strip('ampS')
print(spam)
# Out:
# BaconSpamEggs

# %%
# chr() and ord()
print(ord("A"))
print(chr(65))
# Out:
# 65
# A

# %% [markdown]
# Practice Program: Table Printer
# For practice, write a function named printTable() that takes a list of lists of strings and displays it in a well-organized table with each column right- justified. Assume that all the inner lists will contain the same number of strings. For example, the value could look like this:

# %%
def printtable(arr):
    n=0
    while n<len(arr[0]):        
        for i in arr:
            m=findmaxlen(i)
            print(i[n].rjust(m),end=" ")
        n+=1
        print()

def findmaxlen(arr):
    m=0
    for i in arr:
        if len(i)>m:
            m=len(i)
    return m    

tableData = [['apples', 'oranges', 'cherries', 'banana'],
             ['Alice', 'Bob', 'Carol', 'David'],
             ['dogs', 'cats', 'moose', 'goose']]
printtable(tableData)
# Out:
#   apples Alice  dogs
#  oranges   Bob  cats
# cherries Carol moose
#   banana David goose
